# %% [markdown]
# # Renaming
# The first function we'll introduce here is rename(), which lets you change index names and/or column names. For example, to change the points column in our dataset to score, we would do:

# %%
import pandas as pd
# pd.set_option('max_rows', 5)
reviews= pd.read_csv("C:\\Users\\user\\Downloads\\notes\\archive\\winemag-data-130k-v2.csv", index_col = 0)

# %%
reviews.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
#view column names
reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
#renaming a column
reviews.rename(columns = {"points": "score"}, inplace = True)

# %%
reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'score', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# rename() lets you rename index or column values by specifying a index or column keyword parameter, respectively. It supports a variety of input formats, but usually a Python dictionary is the most convenient. Here is an example using it to rename some elements of the index.

# %%
#renaming the index
reviews.rename(index = {0: "firstnumber", 2: "thirdnumber"}, inplace = True)
reviews.head(3)
# Out:
#               country                                        description  \
# firstnumber     Italy  Aromas include tropical fruit, broom, brimston...
# 1            Portugal  This is ripe and fruity, a wine that is smooth...
# thirdnumber        US  Tart and snappy, the flavors of lime flesh and...
#
#               designation  score  price           province           region_1  \
# firstnumber  Vulkà Bianco     87    NaN  Sicily & Sardinia               Etna
# 1                Avidagos     87   15.0              Douro                NaN
# thirdnumber           NaN     87   14.0             Oregon  Willamette Valley
#
#                       region_2    taster_name taster_twitter_handle  \
# firstnumber                NaN  Kerin O’Keefe          @kerinokeefe
# 1                          NaN     Roger Voss            @vossroger
# thirdnumber  Willamette Valley   Paul Gregutt           @paulgwine
#
#                                                      title         variety  \
# firstnumber              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1            Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# thirdnumber  Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
#
#                           winery
# firstnumber              Nicosia
# 1            Quinta dos Avidagos
# thirdnumber            Rainstorm

# %% [markdown]
# You'll probably rename columns very often, but rename index values very rarely. For that, set_index() is usually more convenient.
#
# Both the row index and the column index can have their own name attribute. The complimentary rename_axis() method may be used to change these names. For example:

# %%
#rename both row and column index
reviews = reviews.rename_axis("wines", axis = 'rows').rename_axis("fields", axis = 1)

# %%
reviews.head(2)
# Out:
# fields        country                                        description  \
# wines
# firstnumber     Italy  Aromas include tropical fruit, broom, brimston...
# 1            Portugal  This is ripe and fruity, a wine that is smooth...
#
# fields        designation  score  price           province region_1 region_2  \
# wines
# firstnumber  Vulkà Bianco     87    NaN  Sicily & Sardinia     Etna      NaN
# 1                Avidagos     87   15.0              Douro      NaN      NaN
#
# fields         taster_name taster_twitter_handle  \
# wines
# firstnumber  Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
#
# fields                                               title         variety  \
# wines
# firstnumber              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1            Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
# fields                    winery
# wines
# firstnumber              Nicosia
# 1            Quinta dos Avidagos

# %%
reviews.isnull().sum()
# Out:
# fields
# country                     63
# description                  0
# designation              37465
# score                        0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
reviews.notnull().sum()
# Out:
# fields
# country                  129908
# description              129971
# designation               92506
# score                    129971
# price                    120975
# province                 129908
# region_1                 108724
# region_2                  50511
# taster_name              103727
# taster_twitter_handle     98758
# title                    129971
# variety                  129970
# winery                   129971
# dtype: int64

# %%
reviews.drop('region_2', axis = 'columns', inplace = True)
reviews.head(2)
# Out:
# fields        country                                        description  \
# wines
# firstnumber     Italy  Aromas include tropical fruit, broom, brimston...
# 1            Portugal  This is ripe and fruity, a wine that is smooth...
#
# fields        designation  score  price           province region_1  \
# wines
# firstnumber  Vulkà Bianco     87    NaN  Sicily & Sardinia     Etna
# 1                Avidagos     87   15.0              Douro      NaN
#
# fields         taster_name taster_twitter_handle  \
# wines
# firstnumber  Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
#
# fields                                               title         variety  \
# wines
# firstnumber              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1            Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
# fields                    winery
# wines
# firstnumber              Nicosia
# 1            Quinta dos Avidagos

# %%
reviews.shape
# Out:
# (129971, 12)

# %%
reviews.dropna(inplace = True)

# %%
reviews.shape
# Out:
# (52106, 12)

# %% [markdown]
# # Combining
# When performing operations on a dataset, we will sometimes need to combine different DataFrames and/or Series in non-trivial ways. Pandas has three core methods for doing this. In order of increasing complexity, these are concat, join(), and merge(). Most of what merge() can do can also be done more simply with join(), so we will omit it and focus on the first two functions here.
#
# The simplest combining method is concat(). Given a list of elements, this function will smush those elements together along an axis.
#
# This is useful when we have data in different DataFrame or Series objects but having the same fields (columns). One example: the YouTube Videos dataset, which splits the data up based on country of origin (e.g. Canada and the UK, in this example). If we want to study multiple countries simultaneously, we can use concat() to smush them together:

# %%
canadian_youtube = pd.read_csv("C:\\Users\\user\\Downloads\\YouTube-data\\CAvideos.csv")
british_youtube = pd.read_csv("C:\\Users\\user\\Downloads\\YouTube-data\\GBvideos.csv")

# %%
canadian_youtube.head(2)
# Out:
#       video_id trending_date                                       title  \
# 0  n1WpP7iowLc      17.14.11  Eminem - Walk On Water (Audio) ft. Beyoncé
# 1  0dBIkQ4Mz1M      17.14.11               PLUSH - Bad Unboxing Fan Mail
#
#   channel_title  category_id              publish_time  \
# 0    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV           23  2017-11-13T17:00:00.000Z
#
#                                                 tags     views   likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651  127794
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
#
#                                          description
# 0  Eminem's new track Walk on Water ft. Beyoncé i...
# 1  STill got a lot of packages. Probably will las...

# %%
canadian_youtube.shape
# Out:
# (40881, 16)

# %%
british_youtube.head(2)
# Out:
#       video_id trending_date                                          title  \
# 0  Jw1Y-zhQURU      17.14.11  John Lewis Christmas Ad 2017 - #MozTheMonster
# 1  3s1rvMFUweQ      17.14.11      Taylor Swift: …Ready for It? (Live) - SNL
#
#          channel_title  category_id              publish_time  \
# 0           John Lewis           26  2017-11-10T07:38:29.000Z
# 1  Saturday Night Live           24  2017-11-12T06:24:44.000Z
#
#                                                 tags    views  likes  \
# 0  christmas|"john lewis christmas"|"john lewis"|...  7224515  55681
# 1  SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...  1053632  25561
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     10247           9479  https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
# 1      2294           2757  https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
#
#                                          description
# 0  Click here to continue the story and make your...
# 1  Musical guest Taylor Swift performs …Ready for...

# %%
british_youtube.shape
# Out:
# (38916, 16)

# %%
#Using concat
ca_uk = pd.concat([canadian_youtube, british_youtube])
ca_uk.head(2)
# Out:
#       video_id trending_date                                       title  \
# 0  n1WpP7iowLc      17.14.11  Eminem - Walk On Water (Audio) ft. Beyoncé
# 1  0dBIkQ4Mz1M      17.14.11               PLUSH - Bad Unboxing Fan Mail
#
#   channel_title  category_id              publish_time  \
# 0    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV           23  2017-11-13T17:00:00.000Z
#
#                                                 tags     views   likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651  127794
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
#
#                                          description
# 0  Eminem's new track Walk on Water ft. Beyoncé i...
# 1  STill got a lot of packages. Probably will las...

# %%
ca_uk.shape
# Out:
# (79797, 16)

# %% [markdown]
# The middlemost combiner in terms of complexity is join(). join() lets you combine different DataFrame objects which have an index in common. For example, to pull down videos that happened to be trending on the same day in both Canada and the UK, we could do the following:

# %%
#Join British to Canada
canadian_youtube.join(british_youtube, lsuffix = "_CAN", rsuffix = '_GB')
# Out:
#       video_id_CAN trending_date_CAN  \
# 0      n1WpP7iowLc          17.14.11
# 1      0dBIkQ4Mz1M          17.14.11
# 2      5qpjK5DgCt4          17.14.11
# 3      d380meD0W0M          17.14.11
# 4      2Vv-BfVoq4g          17.14.11
# ...            ...               ...
# 40876  sGolxsMSGfQ          18.14.06
# 40877  8HNuRNi8t70          18.14.06
# 40878  GWlKEM3m2EE          18.14.06
# 40879  lbMKLzQ4cNQ          18.14.06
# 40880  POTgw38-m58          18.14.06
#
#                                                title_CAN channel_title_CAN  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...                                                  ...               ...
# 40876                       HOW2: How to Solve a Mystery   Annoying Orange
# 40877                   Eli Lik Lik Episode 13 Partie 01  Elhiwar Ettounsi
# 40878  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...    Kingdom Hearts
# 40879                   Trump Advisor Grovels To Trudeau   The Young Turks
# 40880                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班          我愛小明星大跟班
#
#        category_id_CAN          publish_time_CAN  \
# 0                   10  2017-11-10T17:00:03.000Z
# 1                   23  2017-11-13T17:00:00.000Z
# 2                   23  2017-11-12T19:05:24.000Z
# 3                   24  2017-11-12T18:01:41.000Z
# 4                   10  2017-11-09T11:04:14.000Z
# ...                ...                       ...
# 40876               24  2018-06-13T18:00:07.000Z
# 40877               24  2018-06-13T19:01:18.000Z
# 40878               20  2018-06-11T17:30:53.000Z
# 40879               25  2018-06-13T04:00:05.000Z
# 40880               24  2018-06-13T16:00:03.000Z
#
#                                                 tags_CAN  views_CAN  \
# 0      Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...   17158579
# 1      plush|"bad unboxing"|"unboxing"|"fan mail"|"id...    1014651
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...    3191434
# 3      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...    2095828
# 4      edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...   33523622
# ...                                                  ...        ...
# 40876  annoying orange|"funny"|"fruit"|"talking"|"ani...      80685
# 40877  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...     103339
# 40878  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...     773347
# 40879  180612__TB02SorryExcuse|"News"|"Politics"|"The...     115225
# 40880  吳宗憲|"吳姍儒"|"小明星大跟班"|"Sandy"|"Jacky wu"|"憲哥"|"中天...     107392
#
#        likes_CAN  dislikes_CAN  ...  \
# 0         787425         43420  ...
# 1         127794          1688  ...
# 2         146035          5339  ...
# 3         132239          1989  ...
# 4        1634130         21082  ...
# ...          ...           ...  ...
# 40876       1701            99  ...
# 40877        460            66  ...
# 40878      25900           224  ...
# 40879       2115           182  ...
# 40880        300            62  ...
#
#                                                  tags_GB    views_GB  \
# 0      christmas|"john lewis christmas"|"john lewis"|...   7224515.0
# 1      SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...   1053632.0
# 2      Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0
# 3      Salford City FC|"Salford City"|"Salford"|"Clas...     27833.0
# 4                                                 [none]      9815.0
# ...                                                  ...         ...
# 40876                                                NaN         NaN
# 40877                                                NaN         NaN
# 40878                                                NaN         NaN
# 40879                                                NaN         NaN
# 40880                                                NaN         NaN
#
#        likes_GB  dislikes_GB  comment_count_GB  \
# 0       55681.0      10247.0            9479.0
# 1       25561.0       2294.0            2757.0
# 2      787420.0      43420.0          125882.0
# 3         193.0         12.0              37.0
# 4          30.0          2.0              30.0
# ...         ...          ...               ...
# 40876       NaN          NaN               NaN
# 40877       NaN          NaN               NaN
# 40878       NaN          NaN               NaN
# 40879       NaN          NaN               NaN
# 40880       NaN          NaN               NaN
#
#                                     thumbnail_link_GB comments_disabled_GB  \
# 0      https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg                False
# 1      https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg                False
# 2      https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg                False
# 3      https://i.ytimg.com/vi/PUTEiSjKwJU/default.jpg                False
# 4      https://i.ytimg.com/vi/rHwDegptbI4/default.jpg                False
# ...                                               ...                  ...
# 40876                                             NaN                  NaN
# 40877                                             NaN                  NaN
# 40878                                             NaN                  NaN
# 40879                                             NaN                  NaN
# 40880                                             NaN                  NaN
#
#       ratings_disabled_GB video_error_or_removed_GB  \
# 0                   False                     False
# 1                   False                     False
# 2                   False                     False
# 3                   False                     False
# 4                   False                     False
# ...                   ...                       ...
# 40876                 NaN                       NaN
# 40877                 NaN                       NaN
# 40878                 NaN                       NaN
# 40879                 NaN                       NaN
# 40880                 NaN                       NaN
#
#                                           description_GB
# 0      Click here to continue the story and make your...
# 1      Musical guest Taylor Swift performs …Ready for...
# 2      Eminem's new track Walk on Water ft. Beyoncé i...
# 3      Salford drew 4-4 against the Class of 92 and F...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 40876                                                NaN
# 40877                                                NaN
# 40878                                                NaN
# 40879                                                NaN
# 40880                                                NaN
#
# [40881 rows x 32 columns]

# %%
#Alternative join
left = canadian_youtube.set_index(['title'])
right = british_youtube.set_index(['title'])

new_ca_uk = left.join(right, lsuffix = '_CAN', rsuffix = '_GB')

# %%
#view data
new_ca_uk.head(2)
# Out:
#                                                    video_id_CAN  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...  PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!           DvPW66IFhMI
#
#                                                    trending_date_CAN  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...          18.04.01
# #1 Fortnite World Rank - 2,323 Solo Wins!                   18.09.03
#
#                                                    channel_title_CAN  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...        Markiplier
# #1 Fortnite World Rank - 2,323 Solo Wins!             AlexRamiGaming
#
#                                                     category_id_CAN  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...               20
# #1 Fortnite World Rank - 2,323 Solo Wins!                        20
#
#                                                             publish_time_CAN  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...  2018-01-03T19:33:53.000Z
# #1 Fortnite World Rank - 2,323 Solo Wins!           2018-03-09T07:15:52.000Z
#
#                                                                                              tags_CAN  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...  getting over it|"markiplier"|"funny moments"|"...
# #1 Fortnite World Rank - 2,323 Solo Wins!           PS4 Battle Royale|"PS4 Pro Battle Royale"|"Bat...
#
#                                                     views_CAN  likes_CAN  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...     835930      47058
# #1 Fortnite World Rank - 2,323 Solo Wins!              212838       5199
#
#                                                     dislikes_CAN  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...          1023
# #1 Fortnite World Rank - 2,323 Solo Wins!                    542
#
#                                                     comment_count_CAN  ...  \
# title                                                                  ...
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...               8250  ...
# #1 Fortnite World Rank - 2,323 Solo Wins!                          11  ...
#
#                                                    tags_GB  views_GB  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...     NaN       NaN
# #1 Fortnite World Rank - 2,323 Solo Wins!              NaN       NaN
#
#                                                     likes_GB  dislikes_GB  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...       NaN          NaN
# #1 Fortnite World Rank - 2,323 Solo Wins!                NaN          NaN
#
#                                                    comment_count_GB  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...              NaN
# #1 Fortnite World Rank - 2,323 Solo Wins!                       NaN
#
#                                                    thumbnail_link_GB  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...               NaN
# #1 Fortnite World Rank - 2,323 Solo Wins!                        NaN
#
#                                                    comments_disabled_GB  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...                  NaN
# #1 Fortnite World Rank - 2,323 Solo Wins!                           NaN
#
#                                                    ratings_disabled_GB  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...                 NaN
# #1 Fortnite World Rank - 2,323 Solo Wins!                          NaN
#
#                                                     video_error_or_removed_GB  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...                        NaN
# #1 Fortnite World Rank - 2,323 Solo Wins!                                 NaN
#
#                                                    description_GB
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...            NaN
# #1 Fortnite World Rank - 2,323 Solo Wins!                     NaN
#
# [2 rows x 30 columns]

# %%
#check shape
new_ca_uk.shape
# Out:
# (85132, 30)

# %% [markdown]
# The lsuffix and rsuffix parameters are necessary here because the data has the same column names in both British and Canadian datasets. If this wasn't true (because, say, we'd renamed them beforehand) we wouldn't need them.
